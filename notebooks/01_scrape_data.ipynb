# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from src.nhl_scraper import time_remaining, nhl_scraper

# %%
import pandas as pd
from nhlpy import NHLClient

# %%
client = NHLClient()

# %%
# Use the Sabres-Red Wings game from March 12, 2025 as the test example
client.schedule.get_weekly_schedule(date="2025-03-12")
game_id = 2024021036

# %%
shots_df,blocks_df,misses_df,goals_df,hits_df,give_take_df,faceoffs_df,pens_df,shifts_df,players_df,games_df,teams_df = nhl_scraper([game_id])

# %%
# Shots-on-goal dataframe
shots_df
# Out:
#           game  home_id home_team  away_id away_team  event_owner  period  \
# 0   2024021036       17       DET        7       BUF           17       1
# 1   2024021036       17       DET        7       BUF           17       1
# 2   2024021036       17       DET        7       BUF            7       1
# 3   2024021036       17       DET        7       BUF           17       1
# 4   2024021036       17       DET        7       BUF            7       1
# 5   2024021036       17       DET        7       BUF            7       1
# 6   2024021036       17       DET        7       BUF            7       1
# 7   2024021036       17       DET        7       BUF           17       1
# 8   2024021036       17       DET        7       BUF           17       1
# 9   2024021036       17       DET        7       BUF            7       1
# 10  2024021036       17       DET        7       BUF           17       1
# 11  2024021036       17       DET        7       BUF           17       1
# 12  2024021036       17       DET        7       BUF            7       1
# 13  2024021036       17       DET        7       BUF            7       1
# 14  2024021036       17       DET        7       BUF           17       2
# 15  2024021036       17       DET        7       BUF           17       2
# 16  2024021036       17       DET        7       BUF           17       2
# 17  2024021036       17       DET        7       BUF           17       2
# 18  2024021036       17       DET        7       BUF            7       2
# 19  2024021036       17       DET        7       BUF            7       2
# 20  2024021036       17       DET        7       BUF            7       2
# 21  2024021036       17       DET        7       BUF            7       2
# 22  2024021036       17       DET        7       BUF           17       2
# 23  2024021036       17       DET        7       BUF           17       2
# 24  2024021036       17       DET        7       BUF            7       2
# 25  2024021036       17       DET        7       BUF            7       2
# 26  2024021036       17       DET        7       BUF            7       2
# 27  2024021036       17       DET        7       BUF           17       2
# 28  2024021036       17       DET        7       BUF            7       2
# 29  2024021036       17       DET        7       BUF           17       2
# 30  2024021036       17       DET        7       BUF           17       2
# 31  2024021036       17       DET        7       BUF           17       3
# 32  2024021036       17       DET        7       BUF           17       3
# 33  2024021036       17       DET        7       BUF           17       3
# 34  2024021036       17       DET        7       BUF           17       3
# 35  2024021036       17       DET        7       BUF            7       3
# 36  2024021036       17       DET        7       BUF            7       3
# 37  2024021036       17       DET        7       BUF           17       3
# 38  2024021036       17       DET        7       BUF            7       3
# 39  2024021036       17       DET        7       BUF            7       3
# 40  2024021036       17       DET        7       BUF            7       3
# 41  2024021036       17       DET        7       BUF            7       3
# 42  2024021036       17       DET        7       BUF           17       3
# 43  2024021036       17       DET        7       BUF            7       3
# 44  2024021036       17       DET        7       BUF            7       3
#
#    period_type   time  event_id  ... away_goalie home_goalie away_skaters  \
# 0          REG  19:17       106  ...           1           1            5
# 1          REG  18:04       125  ...           1           1            5
# 2          REG  17:54       132  ...           1           1            5
# 3          REG  17:03       139  ...           1           1            5
# 4          REG  14:54       167  ...           1           1            5
# 5          REG  14:51       168  ...           1           1            5
# 6          REG  13:05       192  ...           1           1            5
# 7          REG  12:58       193  ...           1           1            5
# 8          REG  07:40       317  ...           1           1            5
# 9          REG  07:10       326  ...           1           1            5
# 10         REG  05:58       340  ...           1           1            5
# 11         REG  03:50       252  ...           1           1            5
# 12         REG  01:49       389  ...           1           1            5
# 13         REG  01:30       396  ...           1           1            4
# 14         REG  18:28       429  ...           1           1            5
# 15         REG  17:46       438  ...           1           1            5
# 16         REG  17:16       443  ...           1           1            5
# 17         REG  15:48       612  ...           1           1            4
# 18         REG  13:23       635  ...           1           1            5
# 19         REG  13:07       638  ...           1           1            5
# 20         REG  12:47       642  ...           1           1            5
# 21         REG  12:13       702  ...           1           1            5
# 22         REG  09:48       728  ...           1           1            5
# 23         REG  07:34       754  ...           1           1            4
# 24         REG  05:38       776  ...           1           1            5
# 25         REG  04:19       799  ...           1           1            5
# 26         REG  03:58       807  ...           1           1            5
# 27         REG  03:56       808  ...           1           1            5
# 28         REG  03:10       814  ...           1           1            5
# 29         REG  03:00       816  ...           1           1            5
# 30         REG  00:41       848  ...           1           1            4
# 31         REG  19:43       259  ...           1           1            3
# 32         REG  19:02       862  ...           1           1            3
# 33         REG  18:38       866  ...           1           1            4
# 34         REG  17:58       260  ...           1           1            5
# 35         REG  17:49       878  ...           1           1            5
# 36         REG  17:15       884  ...           1           1            5
# 37         REG  15:35       907  ...           1           1            5
# 38         REG  15:06       912  ...           1           1            5
# 39         REG  13:40       929  ...           1           1            5
# 40         REG  13:36       930  ...           1           1            5
# 41         REG  11:01       963  ...           1           1            5
# 42         REG  08:31      1001  ...           1           1            5
# 43         REG  01:28      1105  ...           1           1            5
# 44         REG  00:29      1122  ...           1           1            4
#
#    home_skaters shot_type shooter_id  goalie_id   x   y  zone
# 0             5     wrist    8481542    8480045 -44  39     O
# 1             5     wrist    8477456    8480045 -72   9     O
# 2             5     wrist    8480802    8475852  69  20     O
# 3             5      slap    8475279    8480045 -32  11     O
# 4             5     wrist    8477949    8475852  58  32     O
# 5             5     wrist    8475722    8475852  83  13     O
# 6             5     wrist    8480839    8475852  73  25     O
# 7             5     wrist    8481725    8480045 -72   7     O
# 8             5      snap    8483464    8480045 -82   2     O
# 9             5      slap    8480839    8475852  39 -31     O
# 10            5      slap    8482762    8480045 -51 -19     O
# 11            5    tip-in    8481725    8480045 -85   6     O
# 12            5      snap    8480807    8475852  73  23     O
# 13            5      snap    8477949    8475852  57 -16     O
# 14            5      slap    8474141    8480045  65  28     O
# 15            5     wrist    8477353    8480045  91  -4     O
# 16            5      snap    8479942    8480045  68  -1     O
# 17            5     wrist    8482078    8480045  78  19     O
# 18            5     wrist    8482097    8475852 -54  20     O
# 19            5      slap    8480839    8475852 -31 -39     O
# 20            5     wrist    8480196    8475852 -44  28     O
# 21            5      snap    8481524    8475852 -78  -7     O
# 22            5     wrist    8481542    8480045  37  -2     O
# 23            5      snap    8477456    8480045  76 -13     O
# 24            5      slap    8480839    8475852 -33 -11     O
# 25            5  backhand    8478413    8475852 -80   5     O
# 26            4     wrist    8480839    8475852 -57   9     O
# 27            4     wrist    8477353    8480045 -46  31     D
# 28            4     wrist    8479420    8475852 -79  -2     O
# 29            4     wrist    8475718    8480045  61 -21     O
# 30            5      slap    8481542    8480045  65 -25     O
# 31            5    tip-in    8477946    8480045 -82  -1     O
# 32            5     wrist    8474141    8480045 -75  16     O
# 33            5     wrist    8474141    8480045 -64 -15     O
# 34            5  backhand    8477456    8480045 -69 -22     O
# 35            5      snap    8481524    8475852  57 -23     O
# 36            5      snap    8480196    8475852  56   5     O
# 37            5    tip-in    8477353    8480045  -4 -11     N
# 38            5     wrist    8480802    8475852  77   9     O
# 39            5     wrist    8479420    8475852  78 -37     O
# 40            5    tip-in    8484145    8475852  78  -6     O
# 41            5     wrist    8483468    8475852  51  15     O
# 42            5    tip-in    8479942    8480045  -1  37     N
# 43            4      slap    8483468    8475852  42 -14     O
# 44            4      snap    8477365    8475852  65  26     O
#
# [45 rows x 21 columns]
